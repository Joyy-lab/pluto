# %%
from matplotlib import pyplot as plt
import numpy as np
from pyPLUTO import pload as pp

# %%
D = pp.pload(5, w_dir="/Users/suzhao/Downloads/PLUTO_4.4patch2/Test_Problems/HD/Stellar_Wind/")
# Out:
# Reading single data file : /Users/suzhao/Downloads/PLUTO_4.4patch2/Test_Problems/HD/Stellar_Wind/data.0005.dbl

# %%
for idx in range(5):
    D = pp.pload(idx, w_dir="/Users/suzhao/Downloads/PLUTO_4.4patch2/Test_Problems/HD/Stellar_Wind/")
    plt.plot(D.x1, D.rho)
    plt.xlim(0, 3)
# Out:
# Reading single data file : /Users/suzhao/Downloads/PLUTO_4.4patch2/Test_Problems/HD/Stellar_Wind/data.0000.dbl
# Reading single data file : /Users/suzhao/Downloads/PLUTO_4.4patch2/Test_Problems/HD/Stellar_Wind/data.0001.dbl
# Reading single data file : /Users/suzhao/Downloads/PLUTO_4.4patch2/Test_Problems/HD/Stellar_Wind/data.0002.dbl
# Reading single data file : /Users/suzhao/Downloads/PLUTO_4.4patch2/Test_Problems/HD/Stellar_Wind/data.0003.dbl
# Reading single data file : /Users/suzhao/Downloads/PLUTO_4.4patch2/Test_Problems/HD/Stellar_Wind/data.0004.dbl

# %%
plt.plot(D.x1, 1.203e8*D.prs/D.rho*0.62)
plt.xlim(0,3)
plt.yscale('log')
ax2 = plt.gca().twinx()
ax2.plot(D.x1, D.vx1, color='C03')

# %%
plt.plot(D.x1, D.tr1)
# plt.yscale('log')
plt.xlim(0, 3)
# Out:
# (0.0, 3.0)
